# %%
import os
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import copy
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque, defaultdict
from tqdm import tqdm
from environments import FrozenLakeManipulationEnv

# %%
# MCTS / AlphaZero params
NUM_SIMS     = 1000       # simulations per move
CPUCT        = 1.41       # PUCT exploration constant
TAU          = 1.0       # temperature for π = N^(1/τ)
# Training params
BATCH_SIZE   = 64
LR           = 1e-3
EVAL_INTERVAL= 1       # eval every self-play games
TARGET_SR    = 0.95      # stop when success rate ≥ 95%
REGULARIZATION = 1e-4    # L2 regularization weight decay constant
MAX_EPISODES = 20 # max number of self-play episodes

NUM_EVAL     = 50
BUFFER_SIZE   = 3000

models_dir = "models"

# %%
class AlphaZeroNet(nn.Module):
    def __init__(self, n_states, n_actions, hidden_dim=128):
        super().__init__()
        self.fc1 = nn.Linear(n_states, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        # policy head
        self.policy_head = nn.Linear(hidden_dim, n_actions)
        # value head
        self.value_head  = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        # x: one-hot or feature vector of shape (batch, n_states)
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        p = F.log_softmax(self.policy_head(h), dim=1)  # log-probs
        v = torch.tanh(self.value_head(h))             # in [-1,1]
        return p, v.squeeze(-1)

# %%
# --- Main Execution ---
def make_env():
    return gym.make("FrozenLake-v1", is_slippery=False, render_mode="ansi")
    # return FrozenLakeManipulationEnv()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)


env    = make_env()
nS, nA = env.observation_space.n, env.action_space.n
net    = AlphaZeroNet(nS, nA).to(device)
opt    = optim.Adam(net.parameters(), lr=LR, weight_decay=REGULARIZATION)
# Out:
# Using device: cpu

# %%
class LearnedMCTSNode:
    def __init__(self, 
                 state,
                 make_env,
                 net,
                 parent=None, 
                 action=None, 
                 prior=0.0,
                 cpuct=1.41,
                 device='cpu',
                 verbose=False):
        
        self.state = state
        self.parent = parent
        self.action = action            # action taken to reach this node
        self.prior = prior              # prior probability of this action
        self.children = {}
        
        self.N = defaultdict(int)       # visit counts per action
        self.W = defaultdict(float)     # total reward per action
        self.Q = defaultdict(float)     # average reward per action (Q = W/N)
        self.reward = 0.0
        self.terminal = False
        
        self.puct_constant = cpuct
        
        self.make_env = make_env
        self.env = make_env()
        self.net = net
        self.device = device
        self.verbose = verbose

    def is_leaf(self):
        return len(self.children) == 0

    def puct(self):
        """Calculate the PUCT value for this node.

        Returns:
            puct_value (float): The PUCT value for this node.
        """
        
        if self.parent.N[self.action] == 0:
            return float("inf")
        
        total_N = sum(self.parent.N.values())
        
        exploitation = self.parent.Q[self.action]
        exploration = self.puct_constant * self.prior * math.sqrt(total_N) / (1 + self.parent.N[self.action])
        
        return exploitation + exploration
        

    def best_puct_child(self):
        return max(self.children.values(), key=lambda child: child.puct())

    def best_child(self):
        return max(self.children.values(), key=lambda child: self.Q[child.action])

    def selection(self):
        """Traverse the tree to select a promising node to expand.
        
        Returns:
            - node  (MCTSNode): The selected node to expand.
            - is_goal (bool): True if the node is a goal state.
        """
        node = self
        while not node.is_leaf():
            node = node.best_puct_child()
            if self.verbose:
                print(f"Selected node {node.state} with visits {node.parent.N[node.action]} and value {node.parent.Q[node.action]}")
        
        return node
    
    
    def expand(self):
        """Expand the current node by simulating the environment and adding child nodes.

        Returns:
            child (LearnedMCTSNode): The child node that is a goal state, if any.
        """
        
        s_tensor = F.one_hot(torch.tensor(self.state), self.env.observation_space.n).float().to(self.device)
        
            
        with torch.no_grad():
            logp, _ = self.net(s_tensor.unsqueeze(0))
            p = torch.exp(logp).cpu().numpy()[0]
        
        for action in range(self.env.action_space.n):
            env_copy = self.make_env()
            env_copy.reset()
            env_copy.unwrapped.s = self.state
            
            obs, reward, terminated, truncated, _ = env_copy.step(action)

            # Only add child if it is not a (non successful) terminal state or if it is not the same state
            # if reward == 0 and terminated or self.state == obs:
            #     continue

            child = LearnedMCTSNode(obs,  
                                    make_env=self.make_env,
                                    parent=self,
                                    action=action, 
                                    prior=p[action],
                                    cpuct=self.puct_constant,
                                    device=self.device,
                                    net=self.net,
                                    verbose=self.verbose)
            
            self.children[action] = child

            if terminated or obs == self.state:
                child.terminal = True
                child.reward = reward if reward == 1 else -1
                
            if reward == 1:
                return child
            
        if self.verbose:
            print(f"Expanded node {self.state} with children: {[c.state for c in self.children.values()]}")
        
        return None
    

    def evaluation(self):
        """Evaluate the current node using the neural network.
        Returns:
            value (float): The value of the current node.
        """
        s_tensor = F.one_hot(torch.tensor(self.state), self.env.observation_space.n).float().to(self.device)
        with torch.no_grad():
            _, value = self.net(s_tensor.unsqueeze(0))
            
        return value.item() 

    def backpropagation(self, value):
        """Propagate the simulation result back up the tree."""
        node = self
        while node:
            parent = node.parent
            if parent:
                parent.N[node.action] += 1
                parent.W[node.action] += value
                parent.Q[node.action] = parent.W[node.action] / parent.N[node.action]
                node = parent
            else:
                break

# %%
def run_mcts(root_node,
             tau=1.0, 
             num_sims=1000):
    """Run MCTS simulations from the given node."""
    
    root_node.expand()
    
    for _ in range(num_sims):
        node = root_node.selection()

        print(f"\nSELECTED NODE: {node.state}, with visits {node.parent.N[node.action]} and value {node.parent.Q[node.action]}\n")
        
        if node.terminal:
            print(f"Terminal node reached: {node.parent.state} -> {node.state}, with reward {node.reward}")
            node.backpropagation(node.reward)
            continue
        
        # Check if the node had been visited before
        if node.parent.N[node.action] > 0:
            # If the node has been visited before, expand it
            goal_node = node.expand()
            
            print(f"\nEXPANDED NODE: {node.state}, with children {[c.state for c in node.children.values()]}")
        
            # If the node is a goal state, select it, otherwise select a random child
            node = goal_node if goal_node is not None else node.best_puct_child()
            
            print(f"selected node {node.state} from children {[c.state for c in node.parent.children.values()]}.")
            print(f"is goal node: {goal_node is not None}\n")
            
            
        # If the node is a terminal state, use its reward as the value
        if node.terminal:
            value = node.reward
            print(f"BACKPROPAGATING REWARD: {value} from terminal node {node.state}")
        else:
            value = node.evaluation() # get value from NN
            print(f"BACKPROPAGATING VALUE: {value} from non-terminal node {node.state}")
            
        node.backpropagation(value)
        
        
        
    counts = np.array([root_node.N[a] for a in range(root_node.env.action_space.n)])
    
    counts = counts**(1 / tau)
    
    pi = counts / counts.sum()
    
    return pi

# %%
root_node = LearnedMCTSNode(state=0,
                            make_env=make_env,
                            net=net,
                            cpuct=CPUCT,
                            device=device,
                            verbose=False)

pi = run_mcts(root_node, tau=1., num_sims=500)
print(pi)
# Out:
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 4, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12379749119281769 from non-terminal node 4
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 4, with visits 1 and value 0.12379749119281769
#
#
# EXPANDED NODE: 4, with children [4, 8, 5, 0]
# selected node 4 from children [4, 8, 5, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 4
#
# SELECTED NODE: 1, with visits 1 and value 0.15063880383968353
#
#
# EXPANDED NODE: 1, with children [0, 5, 2, 1]
# selected node 0 from children [0, 5, 2, 1].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 8, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 8, with visits 1 and value 0.1482727825641632
#
#
# EXPANDED NODE: 8, with children [8, 12, 9, 4]
# selected node 8 from children [8, 12, 9, 4].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 8
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 0, with visits 1 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 2, with visits 1 and value 0.12469911575317383
#
#
# EXPANDED NODE: 2, with children [1, 6, 3, 2]
# selected node 1 from children [1, 6, 3, 2].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 6, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.14548319578170776 from non-terminal node 6
#
# SELECTED NODE: 3, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.10875832289457321 from non-terminal node 3
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 6, with visits 1 and value 0.14548319578170776
#
#
# EXPANDED NODE: 6, with children [5, 10, 7, 2]
# selected node 5 from children [5, 10, 7, 2].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 5
#
# SELECTED NODE: 0, with visits 1 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 4, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12379749119281769 from non-terminal node 4
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 1, with visits 1 and value 0.15063880383968353
#
#
# EXPANDED NODE: 1, with children [0, 5, 2, 1]
# selected node 0 from children [0, 5, 2, 1].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 3, with visits 1 and value 0.10875832289457321
#
#
# EXPANDED NODE: 3, with children [2, 7, 3, 3]
# selected node 2 from children [2, 7, 3, 3].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 4, with visits 1 and value 0.12379749119281769
#
#
# EXPANDED NODE: 4, with children [4, 8, 5, 0]
# selected node 4 from children [4, 8, 5, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 4
#
# SELECTED NODE: 12, with visits 0 and value 0.0
#
# Terminal node reached: 8 -> 12, with reward -1
#
# SELECTED NODE: 7, with visits 0 and value 0.0
#
# Terminal node reached: 3 -> 7, with reward -1
#
# SELECTED NODE: 0, with visits 2 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 5, with visits 1 and value -1.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 4, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12379749119281769 from non-terminal node 4
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 4, with visits 1 and value 0.12379749119281769
#
#
# EXPANDED NODE: 4, with children [4, 8, 5, 0]
# selected node 4 from children [4, 8, 5, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 4
#
# SELECTED NODE: 0, with visits 2 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 1, with visits 1 and value 0.15063880383968353
#
#
# EXPANDED NODE: 1, with children [0, 5, 2, 1]
# selected node 0 from children [0, 5, 2, 1].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 1, with visits 1 and value -1.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 9, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12182943522930145 from non-terminal node 9
#
# SELECTED NODE: 4, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12379749119281769 from non-terminal node 4
#
# SELECTED NODE: 4, with visits 1 and value 0.12379749119281769
#
#
# EXPANDED NODE: 4, with children [4, 8, 5, 0]
# selected node 4 from children [4, 8, 5, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 4
#
# SELECTED NODE: 9, with visits 1 and value 0.12182943522930145
#
#
# EXPANDED NODE: 9, with children [8, 13, 10, 5]
# selected node 8 from children [8, 13, 10, 5].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 13, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1350458860397339 from non-terminal node 13
#
# SELECTED NODE: 10, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12921647727489471 from non-terminal node 10
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 9 -> 5, with reward -1
#
# SELECTED NODE: 13, with visits 1 and value 0.1350458860397339
#
#
# EXPANDED NODE: 13, with children [12, 13, 14, 9]
# selected node 12 from children [12, 13, 14, 9].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 12
#
# SELECTED NODE: 0, with visits 3 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 8, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 5, with visits 1 and value -1.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 4, with visits 1 and value -1.0
#
# Terminal node reached: 4 -> 4, with reward -1
#
# SELECTED NODE: 1, with visits 1 and value 0.15063880383968353
#
#
# EXPANDED NODE: 1, with children [0, 5, 2, 1]
# selected node 0 from children [0, 5, 2, 1].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 0, with visits 3 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 3, with visits 0 and value 0.0
#
# Terminal node reached: 3 -> 3, with reward -1
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 8, with visits 1 and value 0.1482727825641632
#
#
# EXPANDED NODE: 8, with children [8, 12, 9, 4]
# selected node 8 from children [8, 12, 9, 4].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 8
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 1, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 0, with visits 4 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 10, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12921647727489471 from non-terminal node 10
#
# SELECTED NODE: 7, with visits 0 and value 0.0
#
# Terminal node reached: 6 -> 7, with reward -1
#
# SELECTED NODE: 8, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 8, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 5, with visits 2 and value -1.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 8, with visits 1 and value 0.1482727825641632
#
#
# EXPANDED NODE: 8, with children [8, 12, 9, 4]
# selected node 8 from children [8, 12, 9, 4].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 8
#
# SELECTED NODE: 0, with visits 4 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 10, with visits 1 and value 0.12921647727489471
#
#
# EXPANDED NODE: 10, with children [9, 14, 11, 6]
# selected node 9 from children [9, 14, 11, 6].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.12182943522930145 from non-terminal node 9
#
# SELECTED NODE: 14, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.0938565582036972 from non-terminal node 14
#
# SELECTED NODE: 11, with visits 0 and value 0.0
#
# Terminal node reached: 10 -> 11, with reward -1
#
# SELECTED NODE: 12, with visits 1 and value -1.0
#
# Terminal node reached: 8 -> 12, with reward -1
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 8, with visits 1 and value 0.1482727825641632
#
#
# EXPANDED NODE: 8, with children [8, 12, 9, 4]
# selected node 8 from children [8, 12, 9, 4].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 8
#
# SELECTED NODE: 5, with visits 2 and value -1.0
#
# Terminal node reached: 4 -> 5, with reward -1
#
# SELECTED NODE: 0, with visits 5 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 4, with visits 2 and value -1.0
#
# Terminal node reached: 4 -> 4, with reward -1
#
# SELECTED NODE: 1, with visits 2 and value -1.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 6, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.14548319578170776 from non-terminal node 6
#
# SELECTED NODE: 6, with visits 1 and value 0.14548319578170776
#
#
# EXPANDED NODE: 6, with children [5, 10, 7, 2]
# selected node 5 from children [5, 10, 7, 2].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 5
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 10, with visits 1 and value 0.12921647727489471
#
#
# EXPANDED NODE: 10, with children [9, 14, 11, 6]
# selected node 9 from children [9, 14, 11, 6].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.12182943522930145 from non-terminal node 9
#
# SELECTED NODE: 2, with visits 1 and value 0.12469911575317383
#
#
# EXPANDED NODE: 2, with children [1, 6, 3, 2]
# selected node 1 from children [1, 6, 3, 2].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 14, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.0938565582036972 from non-terminal node 14
#
# SELECTED NODE: 6, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.14548319578170776 from non-terminal node 6
#
# SELECTED NODE: 3, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.10875832289457321 from non-terminal node 3
#
# SELECTED NODE: 11, with visits 0 and value 0.0
#
# Terminal node reached: 10 -> 11, with reward -1
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 2, with visits 1 and value -1.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 6, with visits 1 and value 0.14548319578170776
#
#
# EXPANDED NODE: 6, with children [5, 10, 7, 2]
# selected node 5 from children [5, 10, 7, 2].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 5
#
# SELECTED NODE: 3, with visits 0 and value 0.0
#
# Terminal node reached: 3 -> 3, with reward -1
#
# SELECTED NODE: 0, with visits 5 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 0, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 8, with visits 1 and value 0.1482727825641632
#
#
# EXPANDED NODE: 8, with children [8, 12, 9, 4]
# selected node 8 from children [8, 12, 9, 4].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 8
#
# SELECTED NODE: 0, with visits 1 and value 0.11375313997268677
#
#
# EXPANDED NODE: 0, with children [0, 4, 1, 0]
# selected node 0 from children [0, 4, 1, 0].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 0
#
# SELECTED NODE: 0, with visits 6 and value -1.0
#
# Terminal node reached: 0 -> 0, with reward -1
#
# SELECTED NODE: 5, with visits 3 and value -1.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 6, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.14548319578170776 from non-terminal node 6
#
# SELECTED NODE: 6, with visits 1 and value 0.14548319578170776
#
#
# EXPANDED NODE: 6, with children [5, 10, 7, 2]
# selected node 5 from children [5, 10, 7, 2].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 5
#
# SELECTED NODE: 2, with visits 1 and value 0.12469911575317383
#
#
# EXPANDED NODE: 2, with children [1, 6, 3, 2]
# selected node 1 from children [1, 6, 3, 2].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.15063880383968353 from non-terminal node 1
#
# SELECTED NODE: 6, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.14548319578170776 from non-terminal node 6
#
# SELECTED NODE: 3, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.10875832289457321 from non-terminal node 3
#
# SELECTED NODE: 2, with visits 0 and value 0.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 6, with visits 1 and value 0.14548319578170776
#
#
# EXPANDED NODE: 6, with children [5, 10, 7, 2]
# selected node 5 from children [5, 10, 7, 2].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 5
#
# SELECTED NODE: 1, with visits 3 and value -1.0
#
# Terminal node reached: 1 -> 1, with reward -1
#
# SELECTED NODE: 14, with visits 1 and value 0.0938565582036972
#
#
# EXPANDED NODE: 14, with children [13, 14, 15]
# selected node 15 from children [13, 14, 15].
# is goal node: True
#
# BACKPROPAGATING REWARD: 1.0 from terminal node 15
#
# SELECTED NODE: 13, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1350458860397339 from non-terminal node 13
#
# SELECTED NODE: 14, with visits 0 and value 0.0
#
# Terminal node reached: 14 -> 14, with reward -1
#
# SELECTED NODE: 9, with visits 1 and value 0.12182943522930145
#
#
# EXPANDED NODE: 9, with children [8, 13, 10, 5]
# selected node 8 from children [8, 13, 10, 5].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.1482727825641632 from non-terminal node 8
#
# SELECTED NODE: 13, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.1350458860397339 from non-terminal node 13
#
# SELECTED NODE: 10, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12921647727489471 from non-terminal node 10
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 9 -> 5, with reward -1
#
# SELECTED NODE: 1, with visits 1 and value 0.15063880383968353
#
#
# EXPANDED NODE: 1, with children [0, 5, 2, 1]
# selected node 0 from children [0, 5, 2, 1].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.11375313997268677 from non-terminal node 0
#
# SELECTED NODE: 3, with visits 1 and value 0.10875832289457321
#
#
# EXPANDED NODE: 3, with children [2, 7, 3, 3]
# selected node 2 from children [2, 7, 3, 3].
# is goal node: False
#
# BACKPROPAGATING VALUE: 0.12469911575317383 from non-terminal node 2
#
# SELECTED NODE: 5, with visits 0 and value 0.0
#
# Terminal node reached: 1 -> 5, with reward -1
#
# SELECTED NODE: 15, with visits 1 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 2 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 3 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 4 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 5 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 6 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 7 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 8 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 9 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 10 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 11 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 12 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 13 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 14 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 15 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 16 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 17 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 18 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 19 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 20 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 21 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 22 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 23 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 24 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 25 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 26 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 13, with visits 1 and value 0.1350458860397339
#
#
# EXPANDED NODE: 13, with children [12, 13, 14, 9]
# selected node 12 from children [12, 13, 14, 9].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 12
#
# SELECTED NODE: 15, with visits 27 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 28 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 29 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 30 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 31 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 32 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 33 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 34 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 35 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 36 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 37 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 38 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 39 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 40 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 41 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 42 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 43 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 44 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 45 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 46 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 47 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 48 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 49 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 50 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 51 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 52 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 53 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 54 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 55 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 56 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 57 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 58 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 59 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 60 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 61 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 62 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 63 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 64 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 65 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 66 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 67 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 68 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 69 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 70 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 71 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 72 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 73 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 74 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 75 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 76 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 77 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 78 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 79 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 80 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 81 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 82 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 83 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 84 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 85 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 86 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 87 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 88 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 89 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 90 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 91 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 92 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 93 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 94 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 95 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 96 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 97 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 5, with visits 1 and value -1.0
#
# Terminal node reached: 6 -> 5, with reward -1
#
# SELECTED NODE: 15, with visits 98 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 99 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 100 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 101 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 102 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 103 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 104 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 105 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 106 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 107 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 108 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 109 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 7, with visits 1 and value -1.0
#
# Terminal node reached: 6 -> 7, with reward -1
#
# SELECTED NODE: 15, with visits 110 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 111 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 112 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 113 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 14, with visits 1 and value -1.0
#
# Terminal node reached: 14 -> 14, with reward -1
#
# SELECTED NODE: 15, with visits 114 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 115 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 116 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 117 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 118 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 119 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 120 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 121 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 122 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 123 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 10, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.12921647727489471 from non-terminal node 10
#
# SELECTED NODE: 15, with visits 124 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 125 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 126 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 127 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 128 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 11, with visits 1 and value -1.0
#
# Terminal node reached: 10 -> 11, with reward -1
#
# SELECTED NODE: 15, with visits 129 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 130 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 131 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 132 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 133 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 134 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 135 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 136 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 137 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 138 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 139 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 140 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 141 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 142 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 143 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 144 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 145 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 146 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 147 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 148 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 149 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 150 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 151 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 152 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 2, with visits 2 and value -1.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 15, with visits 153 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 154 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 155 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 156 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 157 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 13, with visits 0 and value 0.0
#
# Terminal node reached: 13 -> 13, with reward -1
#
# SELECTED NODE: 15, with visits 158 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 159 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 160 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 161 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 162 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 163 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 164 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 165 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 166 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 167 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 7, with visits 0 and value 0.0
#
# Terminal node reached: 6 -> 7, with reward -1
#
# SELECTED NODE: 15, with visits 168 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 169 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 170 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 171 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 172 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 173 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 174 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 175 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 176 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 177 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 178 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 179 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 180 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 181 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 182 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 183 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 184 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 185 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 186 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 187 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 188 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 189 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 190 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 191 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 192 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 193 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 194 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 195 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 196 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 197 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 198 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 199 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 200 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 201 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 202 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 203 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 204 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 205 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 206 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 207 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 208 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 209 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 210 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 211 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 212 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 213 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 214 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 215 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 216 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 217 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 218 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 219 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 220 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 221 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 222 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 223 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 224 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 225 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 226 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 227 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 228 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 229 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 230 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 231 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 232 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 233 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 234 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 235 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 236 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 237 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 238 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 239 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 240 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 241 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 242 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 243 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 244 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 245 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 246 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 247 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 248 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 249 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 250 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 251 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 252 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 253 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 254 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 14, with visits 2 and value -1.0
#
# Terminal node reached: 14 -> 14, with reward -1
#
# SELECTED NODE: 5, with visits 2 and value -1.0
#
# Terminal node reached: 6 -> 5, with reward -1
#
# SELECTED NODE: 15, with visits 255 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 256 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 257 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 258 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 259 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 260 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 261 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 262 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 263 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 264 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 265 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 266 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 267 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 268 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 269 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 270 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 271 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 272 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 273 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 274 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 275 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 276 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 277 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 278 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 279 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 7, with visits 2 and value -1.0
#
# Terminal node reached: 6 -> 7, with reward -1
#
# SELECTED NODE: 15, with visits 280 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 281 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 282 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 283 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 284 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 285 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 286 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 287 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 288 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 289 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 290 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 291 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 292 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 293 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 294 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 295 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 296 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 297 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 298 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 299 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 300 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 301 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 302 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 303 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 304 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 305 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 11, with visits 2 and value -1.0
#
# Terminal node reached: 10 -> 11, with reward -1
#
# SELECTED NODE: 15, with visits 306 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 307 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 308 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 309 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 310 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 311 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 312 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 313 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 314 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 315 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 316 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 317 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 318 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 319 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 320 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 321 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 322 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 323 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 324 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 325 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 326 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 327 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 328 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 329 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 330 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 331 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 2, with visits 3 and value -1.0
#
# Terminal node reached: 2 -> 2, with reward -1
#
# SELECTED NODE: 15, with visits 332 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 333 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 334 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 335 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 336 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 337 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 338 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 339 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 340 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 341 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 342 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 343 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 344 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 345 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 13, with visits 1 and value 0.1350458860397339
#
#
# EXPANDED NODE: 13, with children [12, 13, 14, 9]
# selected node 12 from children [12, 13, 14, 9].
# is goal node: False
#
# BACKPROPAGATING REWARD: -1 from terminal node 12
#
# SELECTED NODE: 15, with visits 346 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 347 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 348 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 349 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 350 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 351 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 352 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 353 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 354 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 15, with visits 355 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
#
# SELECTED NODE: 14, with visits 0 and value 0.0
#
# BACKPROPAGATING VALUE: 0.0938565582036972 from non-terminal node 14
#
# SELECTED NODE: 15, with visits 356 and value 1.0
#
# Terminal node reached: 14 -> 15, with reward 1.0
# [0.012 0.092 0.882 0.014]

# %%
env = make_env()
env.reset()
env.render()
node = root_node
trajectory = []
trajectory.append((node.state, None, 0))
while not node.is_leaf():
    prev_node = node
    node = prev_node.best_child()
    trajectory.append((node.state, node.action, node.parent.Q[node.action]))
    print(f"Best action from state {prev_node.state} to state {node.state} with value {node.parent.Q[node.action]}")
    env.step(node.action)
    print(env.render())
# Out:
# Best action from state 0 to state 1 with value 0.8275279130600591
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Best action from state 1 to state 2 with value 0.8736741070891654
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Best action from state 2 to state 6 with value 0.9102544542590598
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Best action from state 6 to state 10 with value 0.9428766608580775
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Best action from state 10 to state 14 with value 0.974944531338375
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Best action from state 14 to state 15 with value 1.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG

# %%
print(f"Action probabilities: {pi}")
# Out:
# Action probabilities: [0.012 0.092 0.882 0.014]
